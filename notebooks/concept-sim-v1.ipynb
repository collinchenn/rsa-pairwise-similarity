# %% [markdown]
# #### NOTE: this is notebook is the first iteration of human-model pairwise RSA.
# A newer and more improvised version of this notebook can be found in notebooks/human_model_rsa_v2.ipynb:
# - Changed model from GPT-2 to Qwen
# - Replace human similarity matrix with machine-generated data
# - Replace mean pooling with last token in subtoken sequence

# %%
# pair_similarities
# key - (pair_1: str, pair_2: str)
# val - similarity_score: int
pair_similarities = {}

with open('WordSim_sense.txt', 'r') as f:
  for line in f:
    pair_1, pair_2, similiarity_score = line.split()
    pair_similarities[(pair_1.split('#', 1)[0], pair_2.split('#', 1)[0])] = float(similiarity_score)

print(pair_similarities)
# Out:
# {('glass', 'metal'): 5.56, ('bird', 'crane'): 7.38, ('coast', 'shore'): 9.1, ('championship', 'tournament'): 8.36, ('football', 'soccer'): 9.03, ('planet', 'moon'): 8.08, ('planet', 'star'): 8.45, ('professor', 'doctor'): 6.62, ('medium', 'radio'): 7.42, ('precedent', 'antecedent'): 6.04, ('murder', 'manslaughter'): 8.53, ('bread', 'butter'): 6.19, ('shower', 'thunderstorm'): 6.31, ('dollar', 'buck'): 9.22, ('king', 'queen'): 8.58, ('lobster', 'food'): 7.81, ('Harvard', 'Yale'): 8.13, ('precedent', 'example'): 5.85, ('car', 'automobile'): 8.94, ('tiger', 'feline'): 8.0, ('cup', 'object'): 3.69, ('century', 'year'): 7.59, ('furnace', 'stove'): 8.79, ('tiger', 'fauna'): 5.62, ('tiger', 'jaguar'): 8.0, ('tiger', 'mammal'): 6.85, ('opera', 'performance'): 6.88, ('money', 'cash'): 9.15, ('vodka', 'gin'): 8.46, ('seafood', 'food'): 8.34, ('cell', 'phone'): 7.81, ('boy', 'lad'): 8.83, ('marathon', 'sprint'): 7.47, ('train', 'car'): 6.31, ('skin', 'eye'): 6.22, ('street', 'avenue'): 8.88, ('street', 'block'): 6.88, ('life', 'death'): 7.88, ('football', 'tennis'): 6.63, ('food', 'fruit'): 7.52, ('travel', 'activity'): 5.0, ('fuck', 'sex'): 9.44, ('seafood', 'lobster'): 8.7, ('cup', 'artifact'): 2.92, ('calculation', 'computation'): 8.44, ('cup', 'entity'): 2.15, ('physics', 'chemistry'): 7.35, ('museum', 'theater'): 7.19, ('money', 'currency'): 9.04, ('bird', 'cock'): 7.1, ('psychology', 'discipline'): 5.58, ('doctor', 'personnel'): 5.0, ('television', 'radio'): 6.77, ('tiger', 'tiger'): 10.0, ('type', 'kind'): 8.97, ('street', 'place'): 6.44, ('bishop', 'rabbi'): 6.69, ('journey', 'voyage'): 9.29, ('vodka', 'brandy'): 8.13, ('psychology', 'science'): 6.71, ('man', 'governor'): 5.25, ('tiger', 'animal'): 7.0, ('cup', 'tableware'): 6.85, ('jaguar', 'cat'): 7.42, ('student', 'professor'): 6.81, ('doctor', 'nurse'): 7.0, ('announcement', 'news'): 7.56, ('dollar', 'yen'): 7.78, ('midday', 'noon'): 9.29, ('hospital', 'infrastructure'): 4.63, ('Arafat', 'Jackson'): 2.5, ('profit', 'loss'): 7.63, ('mile', 'kilometer'): 8.66, ('magician', 'wizard'): 9.02, ('phone', 'equipment'): 7.13, ('rock', 'jazz'): 7.59, ('liquid', 'water'): 7.89, ('plane', 'car'): 5.77, ('psychology', 'psychiatry'): 8.08, ('man', 'woman'): 8.3, ('cucumber', 'potato'): 5.92, ('tiger', 'organism'): 4.77, ('wood', 'forest'): 7.73, ('money', 'dollar'): 8.42, ('Mexico', 'Brazil'): 7.44, ('lobster', 'wine'): 5.7, ('football', 'basketball'): 6.81, ('food', 'rooster'): 4.42, ('planet', 'sun'): 8.02, ('asylum', 'madhouse'): 8.87, ('king', 'rook'): 5.92, ('tiger', 'carnivore'): 7.08, ('dividend', 'payment'): 7.63, ('tiger', 'cat'): 7.35, ('aluminum', 'metal'): 7.83, ('Japanese', 'American'): 6.5, ('gem', 'jewel'): 8.96}

# %%
# n_pair_similarities
# normalized pair_similarities, bounded score to [0,1]
n_pair_similarities = {k: round(v/10, 3) for k, v in pair_similarities.items()}
print(n_pair_similarities)
# Out:
# {('glass', 'metal'): 0.556, ('bird', 'crane'): 0.738, ('coast', 'shore'): 0.91, ('championship', 'tournament'): 0.836, ('football', 'soccer'): 0.903, ('planet', 'moon'): 0.808, ('planet', 'star'): 0.845, ('professor', 'doctor'): 0.662, ('medium', 'radio'): 0.742, ('precedent', 'antecedent'): 0.604, ('murder', 'manslaughter'): 0.853, ('bread', 'butter'): 0.619, ('shower', 'thunderstorm'): 0.631, ('dollar', 'buck'): 0.922, ('king', 'queen'): 0.858, ('lobster', 'food'): 0.781, ('Harvard', 'Yale'): 0.813, ('precedent', 'example'): 0.585, ('car', 'automobile'): 0.894, ('tiger', 'feline'): 0.8, ('cup', 'object'): 0.369, ('century', 'year'): 0.759, ('furnace', 'stove'): 0.879, ('tiger', 'fauna'): 0.562, ('tiger', 'jaguar'): 0.8, ('tiger', 'mammal'): 0.685, ('opera', 'performance'): 0.688, ('money', 'cash'): 0.915, ('vodka', 'gin'): 0.846, ('seafood', 'food'): 0.834, ('cell', 'phone'): 0.781, ('boy', 'lad'): 0.883, ('marathon', 'sprint'): 0.747, ('train', 'car'): 0.631, ('skin', 'eye'): 0.622, ('street', 'avenue'): 0.888, ('street', 'block'): 0.688, ('life', 'death'): 0.788, ('football', 'tennis'): 0.663, ('food', 'fruit'): 0.752, ('travel', 'activity'): 0.5, ('fuck', 'sex'): 0.944, ('seafood', 'lobster'): 0.87, ('cup', 'artifact'): 0.292, ('calculation', 'computation'): 0.844, ('cup', 'entity'): 0.215, ('physics', 'chemistry'): 0.735, ('museum', 'theater'): 0.719, ('money', 'currency'): 0.904, ('bird', 'cock'): 0.71, ('psychology', 'discipline'): 0.558, ('doctor', 'personnel'): 0.5, ('television', 'radio'): 0.677, ('tiger', 'tiger'): 1.0, ('type', 'kind'): 0.897, ('street', 'place'): 0.644, ('bishop', 'rabbi'): 0.669, ('journey', 'voyage'): 0.929, ('vodka', 'brandy'): 0.813, ('psychology', 'science'): 0.671, ('man', 'governor'): 0.525, ('tiger', 'animal'): 0.7, ('cup', 'tableware'): 0.685, ('jaguar', 'cat'): 0.742, ('student', 'professor'): 0.681, ('doctor', 'nurse'): 0.7, ('announcement', 'news'): 0.756, ('dollar', 'yen'): 0.778, ('midday', 'noon'): 0.929, ('hospital', 'infrastructure'): 0.463, ('Arafat', 'Jackson'): 0.25, ('profit', 'loss'): 0.763, ('mile', 'kilometer'): 0.866, ('magician', 'wizard'): 0.902, ('phone', 'equipment'): 0.713, ('rock', 'jazz'): 0.759, ('liquid', 'water'): 0.789, ('plane', 'car'): 0.577, ('psychology', 'psychiatry'): 0.808, ('man', 'woman'): 0.83, ('cucumber', 'potato'): 0.592, ('tiger', 'organism'): 0.477, ('wood', 'forest'): 0.773, ('money', 'dollar'): 0.842, ('Mexico', 'Brazil'): 0.744, ('lobster', 'wine'): 0.57, ('football', 'basketball'): 0.681, ('food', 'rooster'): 0.442, ('planet', 'sun'): 0.802, ('asylum', 'madhouse'): 0.887, ('king', 'rook'): 0.592, ('tiger', 'carnivore'): 0.708, ('dividend', 'payment'): 0.763, ('tiger', 'cat'): 0.735, ('aluminum', 'metal'): 0.783, ('Japanese', 'American'): 0.65, ('gem', 'jewel'): 0.896}

# %%
import json

def encode_dict_to_json(data: dict, filename: str) -> None:
  """
  Encode the pair_similarities so that we can store tuples
  while following JSON formatting by seperating keys with '|'
  """
  encoded_dict = {k1 + '|' + k2: v for (k1,k2), v in data.items()}
  with open(filename, 'w') as f:
    json.dump(encoded_dict, f, indent=4)
    print("Dictionary saved as ", filename)

def decode_json_to_dict(filename: str) -> dict:
  """
  Decode the pair_similarities, removing the '|' from the keys
  and turning the keys back into a tuple format
  """
  with open(filename, 'r') as f:
    data = json.load(f)
  decoded_dict = {tuple(k.split('|')): val for k, val in data.items()}
  return decoded_dict

encode_dict_to_json(n_pair_similarities, 'n_pair_similarities')
print(decode_json_to_dict("n_pair_similarities"))
# Out:
# Dictionary saved as  n_pair_similarities
# {('glass', 'metal'): 0.556, ('bird', 'crane'): 0.738, ('coast', 'shore'): 0.91, ('championship', 'tournament'): 0.836, ('football', 'soccer'): 0.903, ('planet', 'moon'): 0.808, ('planet', 'star'): 0.845, ('professor', 'doctor'): 0.662, ('medium', 'radio'): 0.742, ('precedent', 'antecedent'): 0.604, ('murder', 'manslaughter'): 0.853, ('bread', 'butter'): 0.619, ('shower', 'thunderstorm'): 0.631, ('dollar', 'buck'): 0.922, ('king', 'queen'): 0.858, ('lobster', 'food'): 0.781, ('Harvard', 'Yale'): 0.813, ('precedent', 'example'): 0.585, ('car', 'automobile'): 0.894, ('tiger', 'feline'): 0.8, ('cup', 'object'): 0.369, ('century', 'year'): 0.759, ('furnace', 'stove'): 0.879, ('tiger', 'fauna'): 0.562, ('tiger', 'jaguar'): 0.8, ('tiger', 'mammal'): 0.685, ('opera', 'performance'): 0.688, ('money', 'cash'): 0.915, ('vodka', 'gin'): 0.846, ('seafood', 'food'): 0.834, ('cell', 'phone'): 0.781, ('boy', 'lad'): 0.883, ('marathon', 'sprint'): 0.747, ('train', 'car'): 0.631, ('skin', 'eye'): 0.622, ('street', 'avenue'): 0.888, ('street', 'block'): 0.688, ('life', 'death'): 0.788, ('football', 'tennis'): 0.663, ('food', 'fruit'): 0.752, ('travel', 'activity'): 0.5, ('fuck', 'sex'): 0.944, ('seafood', 'lobster'): 0.87, ('cup', 'artifact'): 0.292, ('calculation', 'computation'): 0.844, ('cup', 'entity'): 0.215, ('physics', 'chemistry'): 0.735, ('museum', 'theater'): 0.719, ('money', 'currency'): 0.904, ('bird', 'cock'): 0.71, ('psychology', 'discipline'): 0.558, ('doctor', 'personnel'): 0.5, ('television', 'radio'): 0.677, ('tiger', 'tiger'): 1.0, ('type', 'kind'): 0.897, ('street', 'place'): 0.644, ('bishop', 'rabbi'): 0.669, ('journey', 'voyage'): 0.929, ('vodka', 'brandy'): 0.813, ('psychology', 'science'): 0.671, ('man', 'governor'): 0.525, ('tiger', 'animal'): 0.7, ('cup', 'tableware'): 0.685, ('jaguar', 'cat'): 0.742, ('student', 'professor'): 0.681, ('doctor', 'nurse'): 0.7, ('announcement', 'news'): 0.756, ('dollar', 'yen'): 0.778, ('midday', 'noon'): 0.929, ('hospital', 'infrastructure'): 0.463, ('Arafat', 'Jackson'): 0.25, ('profit', 'loss'): 0.763, ('mile', 'kilometer'): 0.866, ('magician', 'wizard'): 0.902, ('phone', 'equipment'): 0.713, ('rock', 'jazz'): 0.759, ('liquid', 'water'): 0.789, ('plane', 'car'): 0.577, ('psychology', 'psychiatry'): 0.808, ('man', 'woman'): 0.83, ('cucumber', 'potato'): 0.592, ('tiger', 'organism'): 0.477, ('wood', 'forest'): 0.773, ('money', 'dollar'): 0.842, ('Mexico', 'Brazil'): 0.744, ('lobster', 'wine'): 0.57, ('football', 'basketball'): 0.681, ('food', 'rooster'): 0.442, ('planet', 'sun'): 0.802, ('asylum', 'madhouse'): 0.887, ('king', 'rook'): 0.592, ('tiger', 'carnivore'): 0.708, ('dividend', 'payment'): 0.763, ('tiger', 'cat'): 0.735, ('aluminum', 'metal'): 0.783, ('Japanese', 'American'): 0.65, ('gem', 'jewel'): 0.896}

# %% [markdown]
# ### Create an ordered vector/list of human similarity values
#
# We will use this ordered vector to create a matching ordered vector of machine activation similarities, and then compare the two equal-sized vectors at each model component.
#
# Because this data is sparse (not every word is paired with every other word), we can't use a matrix anymore. So let's use an ordered vector/list instead. Save the (ordered) mapping of [word pair tuple] to [index in the list of similarities] so that we can use the same tuple to create the corresponding vector/list of machine similarities

# %%
ordered_pairs = sorted(n_pair_similarities.keys()) # lexographically sorted by keys

human_sim_vec = [n_pair_similarities[pair] for pair in ordered_pairs]
ovector_mapping = {pair: i for i, pair in enumerate(ordered_pairs)}

print("Length:", len(human_sim_vec), "pairs")
print("Human similarity vector:", human_sim_vec)
print("Mapping:                ", ovector_mapping)
# Out:
# Length: 97 pairs
# Human similarity vector: [0.25, 0.813, 0.65, 0.744, 0.783, 0.756, 0.887, 0.71, 0.738, 0.669, 0.883, 0.619, 0.844, 0.894, 0.781, 0.759, 0.836, 0.91, 0.592, 0.292, 0.215, 0.369, 0.685, 0.763, 0.7, 0.5, 0.922, 0.778, 0.752, 0.442, 0.681, 0.903, 0.663, 0.944, 0.879, 0.896, 0.556, 0.463, 0.742, 0.929, 0.858, 0.592, 0.788, 0.789, 0.781, 0.57, 0.902, 0.525, 0.83, 0.747, 0.742, 0.929, 0.866, 0.915, 0.904, 0.842, 0.853, 0.719, 0.688, 0.713, 0.735, 0.577, 0.808, 0.845, 0.802, 0.604, 0.585, 0.662, 0.763, 0.558, 0.808, 0.671, 0.759, 0.834, 0.87, 0.631, 0.622, 0.888, 0.688, 0.644, 0.681, 0.677, 0.7, 0.708, 0.735, 0.562, 0.8, 0.8, 0.685, 0.477, 1.0, 0.631, 0.5, 0.897, 0.813, 0.846, 0.773]
# Mapping:                 {('Arafat', 'Jackson'): 0, ('Harvard', 'Yale'): 1, ('Japanese', 'American'): 2, ('Mexico', 'Brazil'): 3, ('aluminum', 'metal'): 4, ('announcement', 'news'): 5, ('asylum', 'madhouse'): 6, ('bird', 'cock'): 7, ('bird', 'crane'): 8, ('bishop', 'rabbi'): 9, ('boy', 'lad'): 10, ('bread', 'butter'): 11, ('calculation', 'computation'): 12, ('car', 'automobile'): 13, ('cell', 'phone'): 14, ('century', 'year'): 15, ('championship', 'tournament'): 16, ('coast', 'shore'): 17, ('cucumber', 'potato'): 18, ('cup', 'artifact'): 19, ('cup', 'entity'): 20, ('cup', 'object'): 21, ('cup', 'tableware'): 22, ('dividend', 'payment'): 23, ('doctor', 'nurse'): 24, ('doctor', 'personnel'): 25, ('dollar', 'buck'): 26, ('dollar', 'yen'): 27, ('food', 'fruit'): 28, ('food', 'rooster'): 29, ('football', 'basketball'): 30, ('football', 'soccer'): 31, ('football', 'tennis'): 32, ('fuck', 'sex'): 33, ('furnace', 'stove'): 34, ('gem', 'jewel'): 35, ('glass', 'metal'): 36, ('hospital', 'infrastructure'): 37, ('jaguar', 'cat'): 38, ('journey', 'voyage'): 39, ('king', 'queen'): 40, ('king', 'rook'): 41, ('life', 'death'): 42, ('liquid', 'water'): 43, ('lobster', 'food'): 44, ('lobster', 'wine'): 45, ('magician', 'wizard'): 46, ('man', 'governor'): 47, ('man', 'woman'): 48, ('marathon', 'sprint'): 49, ('medium', 'radio'): 50, ('midday', 'noon'): 51, ('mile', 'kilometer'): 52, ('money', 'cash'): 53, ('money', 'currency'): 54, ('money', 'dollar'): 55, ('murder', 'manslaughter'): 56, ('museum', 'theater'): 57, ('opera', 'performance'): 58, ('phone', 'equipment'): 59, ('physics', 'chemistry'): 60, ('plane', 'car'): 61, ('planet', 'moon'): 62, ('planet', 'star'): 63, ('planet', 'sun'): 64, ('precedent', 'antecedent'): 65, ('precedent', 'example'): 66, ('professor', 'doctor'): 67, ('profit', 'loss'): 68, ('psychology', 'discipline'): 69, ('psychology', 'psychiatry'): 70, ('psychology', 'science'): 71, ('rock', 'jazz'): 72, ('seafood', 'food'): 73, ('seafood', 'lobster'): 74, ('shower', 'thunderstorm'): 75, ('skin', 'eye'): 76, ('street', 'avenue'): 77, ('street', 'block'): 78, ('street', 'place'): 79, ('student', 'professor'): 80, ('television', 'radio'): 81, ('tiger', 'animal'): 82, ('tiger', 'carnivore'): 83, ('tiger', 'cat'): 84, ('tiger', 'fauna'): 85, ('tiger', 'feline'): 86, ('tiger', 'jaguar'): 87, ('tiger', 'mammal'): 88, ('tiger', 'organism'): 89, ('tiger', 'tiger'): 90, ('train', 'car'): 91, ('travel', 'activity'): 92, ('type', 'kind'): 93, ('vodka', 'brandy'): 94, ('vodka', 'gin'): 95, ('wood', 'forest'): 96}

# %%
# %pip install rsatoolbox
# %pip install transformer_lens
# %pip install circuitsvis
#%pip install numpy==1.26.4
# Install a faster Node version
# !curl -fsSL https://deb.nodesource.com/setup_16.x | sudo -E bash -; sudo apt-get install -y nodejs  # noqa

# Import utils

import circuitsvis as cv
import torch
import torch.nn as nn
import einops
from fancy_einsum import einsum
import tqdm.auto as tqdm
import pandas as pd
import plotly.express as px

from jaxtyping import Float
from functools import partial

# Import transformer_lens

import transformer_lens.utils as utils
from transformer_lens.hook_points import (
    HookPoint,
)  # hooking utilities
from transformer_lens import HookedTransformer, FactoredMatrix

# set automatic differentiation off to save memory, bc only inference here, no training
# TODO: switch this if training/fine-tuning/interfering
torch.set_grad_enabled(False)

# Plotting helper functions

def imshow(tensor, renderer=None, xaxis="", yaxis="", **kwargs):
    px.imshow(utils.to_numpy(tensor), color_continuous_midpoint=0.0, color_continuous_scale="RdBu", labels={"x":xaxis, "y":yaxis}, **kwargs).show(renderer)

def line(tensor, renderer=None, xaxis="", yaxis="", **kwargs):
    px.line(utils.to_numpy(tensor), labels={"x":xaxis, "y":yaxis}, **kwargs).show(renderer)

def scatter(x, y, xaxis="", yaxis="", caxis="", renderer=None, **kwargs):
    x = utils.to_numpy(x)
    y = utils.to_numpy(y)
    px.scatter(y=y, x=x, labels={"x":xaxis, "y":yaxis, "color":caxis}, **kwargs).show(renderer)

# Model setup

device = utils.get_device()
model = HookedTransformer.from_pretrained("gpt2-small", device=device)

# Cache all activations (do less to save memory)

gpt2_text = "What is the difference between a pet fish and a fish?"
gpt2_tokens = model.to_tokens(gpt2_text)
print(gpt2_tokens.device)
gpt2_logits, gpt2_cache = model.run_with_cache(gpt2_tokens, remove_batch_dim=True)
# Out:
# Requirement already satisfied: rsatoolbox in /usr/local/lib/python3.12/dist-packages (0.3.0)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.12/dist-packages (from rsatoolbox) (1.26.4)
# Requirement already satisfied: scipy>=1.10.1 in /usr/local/lib/python3.12/dist-packages (from rsatoolbox) (1.16.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from rsatoolbox) (1.6.1)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.12/dist-packages (from rsatoolbox) (0.25.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from rsatoolbox) (2.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from rsatoolbox) (3.10.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.12/dist-packages (from rsatoolbox) (3.15.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from rsatoolbox) (4.67.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from rsatoolbox) (1.5.2)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.12/dist-packages (from rsatoolbox) (3.5)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->rsatoolbox) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->rsatoolbox) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->rsatoolbox) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->rsatoolbox) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->rsatoolbox) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->rsatoolbox) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->rsatoolbox) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->rsatoolbox) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->rsatoolbox) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->rsatoolbox) (2025.2)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.12/dist-packages (from scikit-image->rsatoolbox) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.12/dist-packages (from scikit-image->rsatoolbox) (2025.10.16)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image->rsatoolbox) (0.4)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->rsatoolbox) (3.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->rsatoolbox) (1.17.0)
# Requirement already satisfied: transformer_lens in /usr/local/lib/python3.12/dist-packages (2.16.1)
# Requirement already satisfied: accelerate>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from transformer_lens) (1.11.0)
# Requirement already satisfied: beartype<0.15.0,>=0.14.1 in /usr/local/lib/python3.12/dist-packages (from transformer_lens) (0.14.1)
# Requirement already satisfied: better-abc<0.0.4,>=0.0.3 in /usr/local/lib/python3.12/dist-packages (from transformer_lens) (0.0.3)
# Requirement already satisfied: datasets>=2.7.1 in /usr/local/lib/python3.12/dist-packages (from transformer_lens) (4.0.0)
# Requirement already satisfied: einops>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from transformer_lens) (0.8.1)
# Requirement already satisfied: fancy-einsum>=0.0.3 in /usr/local/lib/python3.12/dist-packages (from transformer_lens) (0.0.3)
# Requirement already satisfied: jaxtyping>=0.2.11 in /usr/local/lib/python3.12/dist-packages (from transformer_lens) (0.3.3)
# Requirement already satisfied: numpy<2,>=1.26 in /usr/local/lib/python3.12/dist-packages (from transformer_lens) (1.26.4)
# Requirement already satisfied: pandas>=1.1.5 in /usr/local/lib/python3.12/dist-packages (from transformer_lens) (2.2.2)
# Requirement already satisfied: rich>=12.6.0 in /usr/local/lib/python3.12/dist-packages (from transformer_lens) (13.9.4)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.12/dist-packages (from transformer_lens) (0.2.1)
# Requirement already satisfied: torch>=2.6 in /usr/local/lib/python3.12/dist-packages (from transformer_lens) (2.8.0+cu126)
# Requirement already satisfied: tqdm>=4.64.1 in /usr/local/lib/python3.12/dist-packages (from transformer_lens) (4.67.1)
# Requirement already satisfied: transformers>=4.51 in /usr/local/lib/python3.12/dist-packages (from transformer_lens) (4.57.1)
# Requirement already satisfied: transformers-stream-generator<0.0.6,>=0.0.5 in /usr/local/lib/python3.12/dist-packages (from transformer_lens) (0.0.5)
# Requirement already satisfied: typeguard<5.0,>=4.2 in /usr/local/lib/python3.12/dist-packages (from transformer_lens) (4.4.4)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from transformer_lens) (4.15.0)
# Requirement already satisfied: wandb>=0.13.5 in /usr/local/lib/python3.12/dist-packages (from transformer_lens) (0.22.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from accelerate>=0.23.0->transformer_lens) (25.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from accelerate>=0.23.0->transformer_lens) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from accelerate>=0.23.0->transformer_lens) (6.0.3)
# Requirement already satisfied: huggingface_hub>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from accelerate>=0.23.0->transformer_lens) (0.36.0)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from accelerate>=0.23.0->transformer_lens) (0.6.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from datasets>=2.7.1->transformer_lens) (3.20.0)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.7.1->transformer_lens) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.7.1->transformer_lens) (0.3.8)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.7.1->transformer_lens) (2.32.4)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets>=2.7.1->transformer_lens) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.7.1->transformer_lens) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.7.1->transformer_lens) (2025.3.0)
# Requirement already satisfied: wadler-lindig>=0.1.3 in /usr/local/lib/python3.12/dist-packages (from jaxtyping>=0.2.11->transformer_lens) (0.1.7)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.1.5->transformer_lens) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.1.5->transformer_lens) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.1.5->transformer_lens) (2025.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.6.0->transformer_lens) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.6.0->transformer_lens) (2.19.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.6->transformer_lens) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.6->transformer_lens) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=2.6->transformer_lens) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.6->transformer_lens) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.6->transformer_lens) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.6->transformer_lens) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=2.6->transformer_lens) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.6->transformer_lens) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.6->transformer_lens) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.6->transformer_lens) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.6->transformer_lens) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.6->transformer_lens) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.6->transformer_lens) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.6->transformer_lens) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.6->transformer_lens) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.6->transformer_lens) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=2.6->transformer_lens) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=2.6->transformer_lens) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.6->transformer_lens) (3.4.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.51->transformer_lens) (2024.11.6)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.51->transformer_lens) (0.22.1)
# Requirement already satisfied: click>=8.0.1 in /usr/local/lib/python3.12/dist-packages (from wandb>=0.13.5->transformer_lens) (8.3.0)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb>=0.13.5->transformer_lens) (3.1.45)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.12/dist-packages (from wandb>=0.13.5->transformer_lens) (4.5.0)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<7,>=3.19.0 in /usr/local/lib/python3.12/dist-packages (from wandb>=0.13.5->transformer_lens) (5.29.5)
# Requirement already satisfied: pydantic<3 in /usr/local/lib/python3.12/dist-packages (from wandb>=0.13.5->transformer_lens) (2.11.10)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb>=0.13.5->transformer_lens) (2.42.1)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.7.1->transformer_lens) (3.13.1)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from gitpython!=3.1.29,>=1.0.0->wandb>=0.13.5->transformer_lens) (4.0.12)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.21.0->accelerate>=0.23.0->transformer_lens) (1.2.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.6.0->transformer_lens) (0.1.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3->wandb>=0.13.5->transformer_lens) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3->wandb>=0.13.5->transformer_lens) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3->wandb>=0.13.5->transformer_lens) (0.4.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=1.1.5->transformer_lens) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets>=2.7.1->transformer_lens) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets>=2.7.1->transformer_lens) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets>=2.7.1->transformer_lens) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets>=2.7.1->transformer_lens) (2025.10.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.6->transformer_lens) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.6->transformer_lens) (3.0.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.7.1->transformer_lens) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.7.1->transformer_lens) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.7.1->transformer_lens) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.7.1->transformer_lens) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.7.1->transformer_lens) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.7.1->transformer_lens) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.7.1->transformer_lens) (1.22.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb>=0.13.5->transformer_lens) (5.0.2)
# Collecting circuitsvis
#   Using cached circuitsvis-1.43.3-py3-none-any.whl.metadata (983 bytes)
# Requirement already satisfied: importlib-metadata>=5.1.0 in /usr/local/lib/python3.12/dist-packages (from circuitsvis) (8.7.0)
# Requirement already satisfied: numpy>=1.26 in /usr/local/lib/python3.12/dist-packages (from circuitsvis) (1.26.4)
# Requirement already satisfied: torch>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from circuitsvis) (2.8.0+cu126)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib-metadata>=5.1.0->circuitsvis) (3.23.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.1->circuitsvis) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.1->circuitsvis) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.1->circuitsvis) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.1->circuitsvis) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.1->circuitsvis) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.1->circuitsvis) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.1->circuitsvis) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.1->circuitsvis) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.1->circuitsvis) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.1->circuitsvis) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.1->circuitsvis) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.1->circuitsvis) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.1->circuitsvis) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.1->circuitsvis) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.1->circuitsvis) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.1->circuitsvis) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.1->circuitsvis) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.1->circuitsvis) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.1->circuitsvis) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.1->circuitsvis) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.1->circuitsvis) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.1->circuitsvis) (3.4.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.1.1->circuitsvis) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.1.1->circuitsvis) (3.0.3)
# Using cached circuitsvis-1.43.3-py3-none-any.whl (1.8 MB)
# Installing collected packages: circuitsvis
# Successfully installed circuitsvis-1.43.3
#
# ================================================================================
# ================================================================================
#
#                               DEPRECATION WARNING
#
#      Node.js 16.x is no longer actively supported!
#
#   You will not receive security or critical stability updates for this version.
#
#   You should migrate to a supported version of Node.js as soon as possible.
#   Use the installation script that corresponds to the version of Node.js you
#   wish to install. e.g.
#
#    * https://deb.nodesource.com/setup_16.x — Node.js 16 "Gallium" (deprecated)
#    * https://deb.nodesource.com/setup_18.x — Node.js 18 "Hydrogen" (Maintenance)
#    * https://deb.nodesource.com/setup_19.x — Node.js 19 "Nineteen" (deprecated)
#    * https://deb.nodesource.com/setup_20.x — Node.js 20 LTS "Iron" (recommended)
#    * https://deb.nodesource.com/setup_21.x — Node.js 21 "Iron" (current)
#
#
#
#   Please see https://github.com/nodejs/Release for details about which
#   version may be appropriate for you.
#
#   The NodeSource Node.js distributions repository contains
#   information both about supported versions of Node.js and supported Linux
#   distributions. To learn more about usage, see the repository:
#    https://github.com/nodesource/distributions
#
# ================================================================================
# ================================================================================
#
# Continuing in 10 seconds ...
#
# 2025-11-04 22:01:59 - Installing pre-requisites
# Get:1 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:2 https://cli.github.com/packages stable InRelease [3,917 B]
# Get:3 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:5 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:6 https://cli.github.com/packages stable/main amd64 Packages [344 B]
# Hit:7 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:8 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Get:10 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [2,102 kB]
# Hit:11 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Get:12 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [3,520 kB]
# Hit:13 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:14 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [5,963 kB]
# Get:15 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,289 kB]
# Get:16 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,822 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:18 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [9,411 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [3,855 kB]
# Get:20 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [6,161 kB]
# Get:21 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,594 kB]
# Fetched 37.1 MB in 2s (17.5 MB/s)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# 42 packages can be upgraded. Run 'apt list --upgradable' to see them.
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ca-certificates is already the newest version (20240203~22.04.1).
# curl is already the newest version (7.81.0-1ubuntu1.21).
# gnupg is already the newest version (2.2.27-3ubuntu2.4).
# gnupg set to manually installed.
# The following NEW packages will be installed:
#   apt-transport-https
# 0 upgraded, 1 newly installed, 0 to remove and 42 not upgraded.
# Need to get 1,510 B of archives.
# After this operation, 170 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 apt-transport-https all 2.4.14 [1,510 B]
# Fetched 1,510 B in 0s (9,342 B/s)
# Selecting previously unselected package apt-transport-https.
# (Reading database ... 125081 files and directories currently installed.)
# Preparing to unpack .../apt-transport-https_2.4.14_all.deb ...
# Unpacking apt-transport-https (2.4.14) ...
# Setting up apt-transport-https (2.4.14) ...
# Hit:1 https://cli.github.com/packages stable InRelease
# Hit:2 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:3 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Get:5 https://deb.nodesource.com/node_16.x nodistro InRelease [12.1 kB]
# Hit:6 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:8 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:9 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:10 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Get:11 https://deb.nodesource.com/node_16.x nodistro/main amd64 Packages [7,253 B]
# Hit:12 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:13 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Fetched 19.4 kB in 1s (18.8 kB/s)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# 42 packages can be upgraded. Run 'apt list --upgradable' to see them.
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# 2025-11-04 22:02:11 - Repository configured successfully. To install Node.js, run: apt install nodejs -y
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   nodejs
# 0 upgraded, 1 newly installed, 0 to remove and 42 not upgraded.
# Need to get 27.5 MB of archives.
# After this operation, 128 MB of additional disk space will be used.
# Get:1 https://deb.nodesource.com/node_16.x nodistro/main amd64 nodejs amd64 16.20.2-1nodesource1 [27.5 MB]
# Fetched 27.5 MB in 0s (108 MB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package nodejs.
# (Reading database ... 125085 files and directories currently installed.)
# Preparing to unpack .../nodejs_16.20.2-1nodesource1_amd64.deb ...
# Unpacking nodejs (16.20.2-1nodesource1) ...
# Setting up nodejs (16.20.2-1nodesource1) ...
# Processing triggers for man-db (2.10.2-1) ...
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Loaded pretrained model gpt2-small into HookedTransformer
# cpu

# %% [markdown]
# ### Run inputs through GPT-2 small, cache activations, run cosine similarity between each layer's activations for each input

# %%
# normalized human similiarity values in the same order as word pairs
human_similarities = human_sim_vec
print("Ordered vector:", human_similarities)
print("Has", len(human_similarities), "values; corresponding to 97 pairs")
# Out:
# Ordered vector: [0.25, 0.813, 0.65, 0.744, 0.783, 0.756, 0.887, 0.71, 0.738, 0.669, 0.883, 0.619, 0.844, 0.894, 0.781, 0.759, 0.836, 0.91, 0.592, 0.292, 0.215, 0.369, 0.685, 0.763, 0.7, 0.5, 0.922, 0.778, 0.752, 0.442, 0.681, 0.903, 0.663, 0.944, 0.879, 0.896, 0.556, 0.463, 0.742, 0.929, 0.858, 0.592, 0.788, 0.789, 0.781, 0.57, 0.902, 0.525, 0.83, 0.747, 0.742, 0.929, 0.866, 0.915, 0.904, 0.842, 0.853, 0.719, 0.688, 0.713, 0.735, 0.577, 0.808, 0.845, 0.802, 0.604, 0.585, 0.662, 0.763, 0.558, 0.808, 0.671, 0.759, 0.834, 0.87, 0.631, 0.622, 0.888, 0.688, 0.644, 0.681, 0.677, 0.7, 0.708, 0.735, 0.562, 0.8, 0.8, 0.685, 0.477, 1.0, 0.631, 0.5, 0.897, 0.813, 0.846, 0.773]
# Has 97 values; corresponding to 97 pairs

# %%
# Extraction of all the unique words that exist within all the pairs
items = sorted(set([w for pair in ovector_mapping for w in pair]))
print("All unique items:", items)
print("Has", len(items), "items; < 97 * 2 since some duplicate items")
# Out:
# All unique items: ['American', 'Arafat', 'Brazil', 'Harvard', 'Jackson', 'Japanese', 'Mexico', 'Yale', 'activity', 'aluminum', 'animal', 'announcement', 'antecedent', 'artifact', 'asylum', 'automobile', 'avenue', 'basketball', 'bird', 'bishop', 'block', 'boy', 'brandy', 'bread', 'buck', 'butter', 'calculation', 'car', 'carnivore', 'cash', 'cat', 'cell', 'century', 'championship', 'chemistry', 'coast', 'cock', 'computation', 'crane', 'cucumber', 'cup', 'currency', 'death', 'discipline', 'dividend', 'doctor', 'dollar', 'entity', 'equipment', 'example', 'eye', 'fauna', 'feline', 'food', 'football', 'forest', 'fruit', 'fuck', 'furnace', 'gem', 'gin', 'glass', 'governor', 'hospital', 'infrastructure', 'jaguar', 'jazz', 'jewel', 'journey', 'kilometer', 'kind', 'king', 'lad', 'life', 'liquid', 'lobster', 'loss', 'madhouse', 'magician', 'mammal', 'man', 'manslaughter', 'marathon', 'medium', 'metal', 'midday', 'mile', 'money', 'moon', 'murder', 'museum', 'news', 'noon', 'nurse', 'object', 'opera', 'organism', 'payment', 'performance', 'personnel', 'phone', 'physics', 'place', 'plane', 'planet', 'potato', 'precedent', 'professor', 'profit', 'psychiatry', 'psychology', 'queen', 'rabbi', 'radio', 'rock', 'rook', 'rooster', 'science', 'seafood', 'sex', 'shore', 'shower', 'skin', 'soccer', 'sprint', 'star', 'stove', 'street', 'student', 'sun', 'tableware', 'television', 'tennis', 'theater', 'thunderstorm', 'tiger', 'tournament', 'train', 'travel', 'type', 'vodka', 'voyage', 'water', 'wine', 'wizard', 'woman', 'wood', 'year', 'yen']
# Has 149 items; < 97 * 2 since some duplicate items

# %% [markdown]
# The goal is to run each unique word through the model, cache all activations, and then use your dictionary/mapping to compute a "machine similarity score" for EACH layer/component (each hook, basically), ONLY for the pairs of words that have human similarity data.

# %% [markdown]
# #### Cache all model activations at each input

# %%
# Logits aren't used for RSA - don't store logits
# into activation_map to reduce memory usage
activation_maps = {}
for word in items:
  toks = model.to_tokens(" " + word, prepend_bos=False)
  _, cache = model.run_with_cache(toks, remove_batch_dim=True)
  activation_maps[word] = cache

# %%
# DEBUG

for i, pair in enumerate(activation_maps.items()):
  if i == 3:
    break
  word, cache = pair
  print(word, len(cache['blocks.0.hook_resid_pre'][0]), cache['blocks.0.hook_resid_pre'][0][:15])
# Out:
# American 768 tensor([ 0.0945, -0.1652,  0.1330, -0.0108,  0.1625, -0.1313, -0.1830, -0.3221,
#          0.0916,  0.0322, -0.1395,  0.0370, -0.1284,  0.0327,  0.0552])
# Arafat 768 tensor([-0.1354, -0.4119,  0.1131, -0.2338, -0.0324, -0.0400, -0.1873, -0.4047,
#         -0.1659,  0.1896,  0.0565,  0.0560, -0.0835,  0.0892,  0.0402])
# Brazil 768 tensor([ 0.0135, -0.1880,  0.1372, -0.1603, -0.0420, -0.0426, -0.1849, -0.2772,
#         -0.1402, -0.1242, -0.1159,  0.0185,  0.1759,  0.2225, -0.0959])

# %%
def get_vector_from_cache(cache, name, layer):
  """
  Grabs the activation matrix for a chosen hook and layer from the word's cache,
  returns as NumPy vector, suitable for cosine similarity analysis

  cache: the full set of intermediate activations produced by some model for some word
  name:  {"resid_post", "mlp_out", "attn_out", "resid_pre", "hook_embed"}
  layer: 0-11 (since we're using GPT-2)
  """
  vector = cache[name, layer].mean(dim=0) # <- mean pool
  return vector.detach().float().cpu().numpy()

# %%
# Hooks of interest
hooks = (
    [("resid_pre",  l) for l in range(model.cfg.n_layers)] +
    [("attn_out",   l) for l in range(model.cfg.n_layers)] +
    [("mlp_out",    l) for l in range(model.cfg.n_layers)] +
    [("resid_post", l) for l in range(model.cfg.n_layers)]
)

# word_to_hook_vecs is a dictionary of dictionaries:
# Each word in _items_ is a key in word_to_hook_vecs
# which maps to a dictionary containing the hooks and
# the respective (mean-pooled) vectors
#
# word_to_hook_vecs[word] = {
#    'resid_pre' :   [array],
#    'attn_out'  :   [array],
#    'mlp_out'   :   [array],
#    'resid_post':   [array]
# }

word_to_hook_vecs = {}
for word, cache in activation_maps.items():
  activations = {}
  for name, layer in hooks:
    hook = f"{name}@{layer}"
    activations[hook] = get_vector_from_cache(cache, name, layer)
  word_to_hook_vecs[word] = activations

# %%
# DEBUG

for i, (word, activations) in enumerate(word_to_hook_vecs.items()):
  if i == 3:
    break
  print(word)
  for hook, vec in activations.items():
    print(vec[:5])
    print(f"{hook}: {vec.shape}")
# Out:
# American
# [ 0.0944553  -0.16521151  0.13300577 -0.01079076  0.16253051]
# resid_pre@0: (768,)
# [-0.594525   -0.33607268  1.1510376   0.2532938  -0.7124848 ]
# resid_pre@1: (768,)
# [-1.0983658 -1.127925   1.2961426 -0.9153471 -0.8540274]
# resid_pre@2: (768,)
# [-4.077264  -4.4940224 -2.1538067 -3.855942  -3.6578398]
# resid_pre@3: (768,)
# [-4.3700905 -4.806858  -2.3877115 -4.170375  -3.7934341]
# resid_pre@4: (768,)
# [-4.7689824 -5.122589  -2.704484  -4.4823017 -3.9399948]
# resid_pre@5: (768,)
# [-4.9054565 -5.32148   -2.8041227 -4.6859784 -3.8626852]
# resid_pre@6: (768,)
# [-5.0885167 -5.392672  -2.8365948 -4.887884  -3.7888205]
# resid_pre@7: (768,)
# [-5.1851473 -5.3358264 -3.0032535 -5.072492  -3.7355182]
# resid_pre@8: (768,)
# [-5.185441  -5.3038073 -3.0961907 -5.2147365 -3.7984648]
# resid_pre@9: (768,)
# [-5.2868166 -5.23069   -3.3410463 -5.330672  -3.7558248]
# resid_pre@10: (768,)
# [-5.383737  -5.043421  -3.668625  -5.4208074 -3.8021927]
# resid_pre@11: (768,)
# [-1.0187595  -0.7319456   1.3075768   0.00590296  0.0094047 ]
# attn_out@0: (768,)
# [ 0.25507322 -0.23201056  0.6811566  -0.22300433  0.3636995 ]
# attn_out@1: (768,)
# [ 0.09862124 -0.19106539 -0.0480901   0.14085415  0.19459367]
# attn_out@2: (768,)
# [ 0.07087822  0.00241798  0.1401203  -0.00770671  0.15292172]
# attn_out@3: (768,)
# [-0.11409552 -0.1458379   0.02617208 -0.03040582  0.07062103]
# attn_out@4: (768,)
# [-0.02048065 -0.10131659  0.11352737 -0.04381955  0.19989596]
# attn_out@5: (768,)
# [-0.03155938 -0.04312933  0.14052129 -0.03849211  0.1085941 ]
# attn_out@6: (768,)
# [-0.05480745  0.0288109   0.07862193 -0.16921428  0.05680642]
# attn_out@7: (768,)
# [-0.04240742  0.00025331  0.06416281 -0.16671973 -0.03357223]
# attn_out@8: (768,)
# [-0.09563028  0.07065762 -0.02413885 -0.17492224  0.06284449]
# attn_out@9: (768,)
# [-0.01384816  0.06218391 -0.0288014  -0.07331033  0.03696517]
# attn_out@10: (768,)
# [4.43091   4.334607  4.277065  4.359061  4.3332276]
# attn_out@11: (768,)
# [ 0.32977924  0.5610844  -0.28954497  0.2581816  -0.88442   ]
# mlp_out@0: (768,)
# [-0.758914  -0.5598418 -0.5360515 -0.9456366 -0.5052421]
# mlp_out@1: (768,)
# [-3.0775194 -3.1750317 -3.4018593 -3.081449  -2.998406 ]
# mlp_out@2: (768,)
# [-0.36370468 -0.3152538  -0.37402508 -0.3067263  -0.28851599]
# mlp_out@3: (768,)
# [-0.28479642 -0.16989341 -0.34294474 -0.28152084 -0.2171817 ]
# mlp_out@4: (768,)
# [-0.11599369 -0.097574   -0.2131661  -0.15985724 -0.12258625]
# mlp_out@5: (768,)
# [-0.15150076 -0.02806278 -0.17299335 -0.16341329 -0.0347295 ]
# mlp_out@6: (768,)
# [-0.04182309  0.02803479 -0.24528041 -0.01539384 -0.00350404]
# mlp_out@7: (768,)
# [ 0.0421136   0.03176614 -0.15709996  0.02447572 -0.02937445]
# mlp_out@8: (768,)
# [-0.00574553  0.00245948 -0.2207166   0.05898724 -0.02020451]
# mlp_out@9: (768,)
# [-0.08307201  0.12508547 -0.2987774  -0.01682519 -0.08333305]
# mlp_out@10: (768,)
# [ 0.17946815  0.5570203  -0.3852088   0.2896435   0.35231492]
# mlp_out@11: (768,)
# [-0.594525   -0.33607268  1.1510376   0.2532938  -0.7124848 ]
# resid_post@0: (768,)
# [-1.0983658 -1.127925   1.2961426 -0.9153471 -0.8540274]
# resid_post@1: (768,)
# [-4.077264  -4.4940224 -2.1538067 -3.855942  -3.6578398]
# resid_post@2: (768,)
# [-4.3700905 -4.806858  -2.3877115 -4.170375  -3.7934341]
# resid_post@3: (768,)
# [-4.7689824 -5.122589  -2.704484  -4.4823017 -3.9399948]
# resid_post@4: (768,)
# [-4.9054565 -5.32148   -2.8041227 -4.6859784 -3.8626852]
# resid_post@5: (768,)
# [-5.0885167 -5.392672  -2.8365948 -4.887884  -3.7888205]
# resid_post@6: (768,)
# [-5.1851473 -5.3358264 -3.0032535 -5.072492  -3.7355182]
# resid_post@7: (768,)
# [-5.185441  -5.3038073 -3.0961907 -5.2147365 -3.7984648]
# resid_post@8: (768,)
# [-5.2868166 -5.23069   -3.3410463 -5.330672  -3.7558248]
# resid_post@9: (768,)
# [-5.383737  -5.043421  -3.668625  -5.4208074 -3.8021927]
# resid_post@10: (768,)
# [-0.7733588  -0.15179336  0.2232309  -0.7721031   0.8833499 ]
# resid_post@11: (768,)
# Arafat
# [-0.12469397 -0.23691593  0.02593728 -0.15029967  0.05930371]
# resid_pre@0: (768,)
# [-0.17892835 -1.0101459  -0.22618622 -0.5503193   1.2435501 ]
# resid_pre@1: (768,)
# [-0.5039733  -1.9044911  -0.90777427 -0.12805605  0.10150045]
# resid_pre@2: (768,)
# [-1.8745543 -3.6935318 -2.4575863 -1.6674486 -1.4809064]
# resid_pre@3: (768,)
# [-1.9994149 -3.5964427 -2.7394147 -2.3126476 -1.343729 ]
# resid_pre@4: (768,)
# [-1.8441441 -3.8693423 -2.6647205 -2.182336  -1.6935791]
# resid_pre@5: (768,)
# [-2.3694704 -4.731288  -2.6960213 -2.1445754 -1.2154702]
# resid_pre@6: (768,)
# [-2.421111   -5.208507   -2.589004   -2.195949   -0.96702766]
# resid_pre@7: (768,)
# [-2.8650897 -5.3404856 -3.4602375 -2.4397042 -0.7497531]
# resid_pre@8: (768,)
# [-3.1107578 -5.17287   -4.1204133 -2.2063062 -0.3992746]
# resid_pre@9: (768,)
# [-4.0473733  -5.0083423  -4.4349337  -2.4634578  -0.12677968]
# resid_pre@10: (768,)
# [-4.0957966  -5.682297   -5.154352   -2.5544     -0.41015017]
# resid_pre@11: (768,)
# [ 0.2150575  -0.44724917  0.27384627 -0.01236849  0.03244027]
# attn_out@0: (768,)
# [-0.10498219 -0.47260952 -0.25546846  0.4475488  -0.3567838 ]
# attn_out@1: (768,)
# [ 0.02699461 -0.1506077  -0.1544041   0.201526    0.10962286]
# attn_out@2: (768,)
# [ 0.06555295  0.01424051  0.13785155 -0.00711126  0.12429838]
# attn_out@3: (768,)
# [-0.12888506 -0.1477248   0.03804518 -0.00674243  0.03969145]
# attn_out@4: (768,)
# [-0.02770923 -0.10776196  0.11010319 -0.02254797  0.20670435]
# attn_out@5: (768,)
# [-0.04816353 -0.03951634  0.11869086 -0.06924584  0.15080623]
# attn_out@6: (768,)
# [-0.08329653 -0.00567217 -0.01642527 -0.14104822  0.0562656 ]
# attn_out@7: (768,)
# [-0.09531976  0.03254218 -0.00721783 -0.19562934 -0.01422855]
# attn_out@8: (768,)
# [-0.34812364  0.16987985 -0.19916068 -0.27182016  0.16504811]
# attn_out@9: (768,)
# [-0.22854286  0.04942116 -0.15143828 -0.07800084  0.02293821]
# attn_out@10: (768,)
# [2.3150885 1.748035  2.072869  2.1952407 2.3741586]
# attn_out@11: (768,)
# [-0.26929188 -0.32598078 -0.52596974 -0.38765118  1.1518061 ]
# mlp_out@0: (768,)
# [-0.22006276 -0.42173558 -0.42611963 -0.02528551 -0.78526574]
# mlp_out@1: (768,)
# [-1.3975756 -1.638433  -1.3954078 -1.7409185 -1.6920297]
# mlp_out@2: (768,)
# [-0.1904136   0.08284836 -0.41967994 -0.63808763  0.01287897]
# mlp_out@3: (768,)
# [ 0.2841559  -0.12517466  0.03664869  0.13705397 -0.38954145]
# mlp_out@4: (768,)
# [-0.497617   -0.7541838  -0.14140385  0.06030866  0.27140445]
# mlp_out@5: (768,)
# [-0.00347729 -0.43770266 -0.01167376  0.01787217  0.09763632]
# mlp_out@6: (768,)
# [-0.36068177 -0.12630653 -0.8548082  -0.10270677  0.16100903]
# mlp_out@7: (768,)
# [-0.15034853  0.1350736  -0.6529582   0.4290271   0.36470708]
# mlp_out@8: (768,)
# [-0.58849174 -0.00535199 -0.1153596   0.0146684   0.10744676]
# mlp_out@9: (768,)
# [ 0.18011984 -0.72337615 -0.5679805  -0.01294144 -0.3063088 ]
# mlp_out@10: (768,)
# [ 0.4089655   0.3037194  -1.1053996   0.25385892 -0.07168686]
# mlp_out@11: (768,)
# [-0.17892835 -1.0101459  -0.22618622 -0.5503193   1.2435501 ]
# resid_post@0: (768,)
# [-0.5039733  -1.9044911  -0.90777427 -0.12805605  0.10150045]
# resid_post@1: (768,)
# [-1.8745543 -3.6935318 -2.4575863 -1.6674486 -1.4809064]
# resid_post@2: (768,)
# [-1.9994149 -3.5964427 -2.7394147 -2.3126476 -1.343729 ]
# resid_post@3: (768,)
# [-1.8441441 -3.8693423 -2.6647205 -2.182336  -1.6935791]
# resid_post@4: (768,)
# [-2.3694704 -4.731288  -2.6960213 -2.1445754 -1.2154702]
# resid_post@5: (768,)
# [-2.421111   -5.208507   -2.589004   -2.195949   -0.96702766]
# resid_post@6: (768,)
# [-2.8650897 -5.3404856 -3.4602375 -2.4397042 -0.7497531]
# resid_post@7: (768,)
# [-3.1107578 -5.17287   -4.1204133 -2.2063062 -0.3992746]
# resid_post@8: (768,)
# [-4.0473733  -5.0083423  -4.4349337  -2.4634578  -0.12677968]
# resid_post@9: (768,)
# [-4.0957966  -5.682297   -5.154352   -2.5544     -0.41015017]
# resid_post@10: (768,)
# [-1.3717424  -3.6305428  -4.186883   -0.10530043  1.8923218 ]
# resid_post@11: (768,)
# Brazil
# [ 0.0135277  -0.18803188  0.13723649 -0.16029733 -0.04200154]
# resid_pre@0: (768,)
# [ 0.13027942 -0.49182665  0.20359316 -0.04199728 -0.13885523]
# resid_pre@1: (768,)
# [-0.52670586 -1.6145215  -0.25159758 -1.0715631  -0.69394815]
# resid_pre@2: (768,)
# [-3.5884342 -5.185167  -3.6668177 -4.0657187 -3.6921115]
# resid_pre@3: (768,)
# [-3.8360753 -5.50146   -3.9095738 -4.384079  -3.83378  ]
# resid_pre@4: (768,)
# [-4.234434  -5.7995305 -4.2328362 -4.664151  -4.0575495]
# resid_pre@5: (768,)
# [-4.386352  -5.9974065 -4.3225083 -4.863301  -3.9953098]
# resid_pre@6: (768,)
# [-4.5874076 -6.064024  -4.368557  -5.0686097 -3.9844735]
# resid_pre@7: (768,)
# [-4.7085614 -5.990673  -4.5794096 -5.238724  -3.9536378]
# resid_pre@8: (768,)
# [-4.7491856 -5.953967  -4.70413   -5.397989  -3.9798625]
# resid_pre@9: (768,)
# [-4.8715525 -5.9036717 -4.970644  -5.492558  -4.0735984]
# resid_pre@10: (768,)
# [-5.046223  -5.725443  -5.374054  -5.4843507 -4.1985946]
# resid_pre@11: (768,)
# [ 1.1251862  -0.44047713 -0.07367935 -0.02834133 -0.03353463]
# attn_out@0: (768,)
# [ 0.4261799  -0.27321708  0.08548961 -0.14742188 -0.04211755]
# attn_out@1: (768,)
# [ 0.09396186 -0.16880246 -0.12897974  0.15961777  0.19319057]
# attn_out@2: (768,)
# [ 0.07872209  0.01372582  0.141198   -0.00133285  0.12130032]
# attn_out@3: (768,)
# [-0.13096564 -0.13442653  0.02387039 -0.01612223  0.06171586]
# attn_out@4: (768,)
# [-0.02312395 -0.11500789  0.1087295  -0.04639854  0.19248308]
# attn_out@5: (768,)
# [-0.02810155 -0.02739863  0.1256815  -0.05250787  0.09290545]
# attn_out@6: (768,)
# [-0.07064693  0.02871994  0.00912513 -0.16379178  0.04357373]
# attn_out@7: (768,)
# [-0.072281    0.00223371  0.03031383 -0.17096978 -0.0057548 ]
# attn_out@8: (768,)
# [-0.09817252  0.0678434  -0.01815884 -0.15296862 -0.01147434]
# attn_out@9: (768,)
# [-0.050754    0.07720612 -0.1104133  -0.02022754 -0.02284962]
# attn_out@10: (768,)
# [4.38448   4.348995  4.1905475 4.470438  4.380913 ]
# attn_out@11: (768,)
# [-1.0084345   0.13668239  0.14003602  0.14664139 -0.06331907]
# mlp_out@0: (768,)
# [-1.0831652  -0.84947777 -0.54068035 -0.8821439  -0.5129754 ]
# mlp_out@1: (768,)
# [-3.1556902 -3.4018428 -3.2862403 -3.153773  -3.1913538]
# mlp_out@2: (768,)
# [-0.32636297 -0.33001903 -0.38395408 -0.31702763 -0.26296878]
# mlp_out@3: (768,)
# [-0.26739317 -0.16364384 -0.34713277 -0.2639498  -0.28548536]
# mlp_out@4: (768,)
# [-0.128794   -0.08286822 -0.19840151 -0.15275112 -0.1302435 ]
# mlp_out@5: (768,)
# [-0.17295407 -0.03921913 -0.17173018 -0.15280093 -0.08206911]
# mlp_out@6: (768,)
# [-0.05050686  0.04463096 -0.2199778  -0.006323   -0.01273799]
# mlp_out@7: (768,)
# [ 0.03165659  0.03447242 -0.15503466  0.01170557 -0.02046994]
# mlp_out@8: (768,)
# [-0.02419445 -0.01754811 -0.24835475  0.05839898 -0.08226151]
# mlp_out@9: (768,)
# [-0.1239166   0.10102288 -0.2929968   0.02843495 -0.1021468 ]
# mlp_out@10: (768,)
# [ 0.34815368  0.4053649  -0.3265895   0.462757    0.16055512]
# mlp_out@11: (768,)
# [ 0.13027942 -0.49182665  0.20359316 -0.04199728 -0.13885523]
# resid_post@0: (768,)
# [-0.52670586 -1.6145215  -0.25159758 -1.0715631  -0.69394815]
# resid_post@1: (768,)
# [-3.5884342 -5.185167  -3.6668177 -4.0657187 -3.6921115]
# resid_post@2: (768,)
# [-3.8360753 -5.50146   -3.9095738 -4.384079  -3.83378  ]
# resid_post@3: (768,)
# [-4.234434  -5.7995305 -4.2328362 -4.664151  -4.0575495]
# resid_post@4: (768,)
# [-4.386352  -5.9974065 -4.3225083 -4.863301  -3.9953098]
# resid_post@5: (768,)
# [-4.5874076 -6.064024  -4.368557  -5.0686097 -3.9844735]
# resid_post@6: (768,)
# [-4.7085614 -5.990673  -4.5794096 -5.238724  -3.9536378]
# resid_post@7: (768,)
# [-4.7491856 -5.953967  -4.70413   -5.397989  -3.9798625]
# resid_post@8: (768,)
# [-4.8715525 -5.9036717 -4.970644  -5.492558  -4.0735984]
# resid_post@9: (768,)
# [-5.046223  -5.725443  -5.374054  -5.4843507 -4.1985946]
# resid_post@10: (768,)
# [-0.31358948 -0.9710828  -1.510096   -0.5511557   0.34287333]
# resid_post@11: (768,)

# %% [markdown]
# #### Compute cosine similarities

# %%
import numpy as np

# Make human_vec (just a numpy'd version of
# human_sim_vec for purposes of computation)
human_vec = np.array(human_sim_vec)
human_vec
# Out:
# array([0.25 , 0.813, 0.65 , 0.744, 0.783, 0.756, 0.887, 0.71 , 0.738,
#        0.669, 0.883, 0.619, 0.844, 0.894, 0.781, 0.759, 0.836, 0.91 ,
#        0.592, 0.292, 0.215, 0.369, 0.685, 0.763, 0.7  , 0.5  , 0.922,
#        0.778, 0.752, 0.442, 0.681, 0.903, 0.663, 0.944, 0.879, 0.896,
#        0.556, 0.463, 0.742, 0.929, 0.858, 0.592, 0.788, 0.789, 0.781,
#        0.57 , 0.902, 0.525, 0.83 , 0.747, 0.742, 0.929, 0.866, 0.915,
#        0.904, 0.842, 0.853, 0.719, 0.688, 0.713, 0.735, 0.577, 0.808,
#        0.845, 0.802, 0.604, 0.585, 0.662, 0.763, 0.558, 0.808, 0.671,
#        0.759, 0.834, 0.87 , 0.631, 0.622, 0.888, 0.688, 0.644, 0.681,
#        0.677, 0.7  , 0.708, 0.735, 0.562, 0.8  , 0.8  , 0.685, 0.477,
#        1.   , 0.631, 0.5  , 0.897, 0.813, 0.846, 0.773])

# %%
# Organized list of activations that we'll use
# for cosine similarity
#['attn_out@0',
# 'attn_out@1',
# 'attn_out@10',
# 'attn_out@11',
# 'attn_out@2',
#     ...
# 'resid_pre@4',
# 'resid_pre@5',
# 'resid_pre@6',
# 'resid_pre@7',
# 'resid_pre@8',
# 'resid_pre@9']
hook_tags = sorted(next(iter(word_to_hook_vecs.values())).keys())

# List of pairs from WordSim
#[('Arafat', 'Jackson'),
# ('Harvard', 'Yale'),
# ('Japanese', 'American'),
#           ...
# ('aluminum', 'metal'),
# ('announcement', 'news'),
# ('asylum', 'madhouse')]
pairs = list(ovector_mapping.keys())

# %%
from numpy.linalg import norm

def cosine(u, v):
  nu, nv = norm(u), norm(v)
  return float(np.dot(u, v)/(nu*nv)) if (nu and nv) else np.nan

cosine_by_hook = {}

# Generate machine_sim for each hook
for tag in hook_tags:
  machine_sim = []
  for (w1, w2) in pairs:
    v1 = word_to_hook_vecs[w1][tag]
    v2 = word_to_hook_vecs[w2][tag]
    machine_sim.append(cosine(v1, v2))
  cosine_by_hook[tag] = np.asarray(machine_sim, dtype=float)

# Display result as table
cosine_df = pd.DataFrame(
  {tag: cosine_by_hook[tag] for tag in hook_tags},
  index=pairs
)
display(cosine_df)
# Out:
#                       attn_out@0  attn_out@1  attn_out@10  attn_out@11  \
# (Arafat, Jackson)       0.726338    0.871980     0.931544     0.998285
# (Harvard, Yale)         0.942272    0.992928     0.989518     1.000000
# (Japanese, American)    0.898009    0.972105     0.984077     1.000000
# (Mexico, Brazil)        0.919369    0.991951     0.989980     1.000000
# (aluminum, metal)       0.919519    0.985299     0.988970     1.000000
# ...                          ...         ...          ...          ...
# (travel, activity)      0.888831    0.970361     0.982840     1.000000
# (type, kind)            0.931656    0.983732     0.989876     1.000000
# (vodka, brandy)         0.865418    0.906386     0.889812     0.997130
# (vodka, gin)            0.908244    0.978006     0.981754     1.000000
# (wood, forest)          0.902382    0.979168     0.990563     1.000000
#
#                       attn_out@2  attn_out@3  attn_out@4  attn_out@5  \
# (Arafat, Jackson)       0.899560    0.996132    0.988263    0.991256
# (Harvard, Yale)         0.993333    0.999420    0.997353    0.998575
# (Japanese, American)    0.977913    0.998193    0.992347    0.996942
# (Mexico, Brazil)        0.991800    0.999164    0.996851    0.998404
# (aluminum, metal)       0.987630    0.998991    0.995462    0.997775
# ...                          ...         ...         ...         ...
# (travel, activity)      0.974468    0.998125    0.992250    0.996055
# (type, kind)            0.979857    0.998684    0.994141    0.997278
# (vodka, brandy)         0.949270    0.995186    0.984927    0.992434
# (vodka, gin)            0.985929    0.998446    0.993334    0.997286
# (wood, forest)          0.979496    0.998776    0.993382    0.996768
#
#                       attn_out@6  attn_out@7  ...  resid_pre@10  resid_pre@11  \
# (Arafat, Jackson)       0.973145    0.978686  ...      0.999237      0.997553
# (Harvard, Yale)         0.997024    0.995956  ...      0.999987      0.999986
# (Japanese, American)    0.992721    0.992320  ...      0.999976      0.999975
# (Mexico, Brazil)        0.996629    0.995908  ...      0.999987      0.999987
# (aluminum, metal)       0.994960    0.995918  ...      0.999981      0.999980
# ...                          ...         ...  ...           ...           ...
# (travel, activity)      0.992548    0.991665  ...      0.999970      0.999969
# (type, kind)            0.993874    0.993992  ...      0.999978      0.999977
# (vodka, brandy)         0.946382    0.963299  ...      0.999083      0.997158
# (vodka, gin)            0.992814    0.993684  ...      0.999977      0.999976
# (wood, forest)          0.993393    0.994402  ...      0.999980      0.999980
#
#                       resid_pre@2  resid_pre@3  resid_pre@4  resid_pre@5  \
# (Arafat, Jackson)        0.994681     0.999672     0.999710     0.999717
# (Harvard, Yale)          0.999641     0.999977     0.999982     0.999984
# (Japanese, American)     0.999360     0.999964     0.999970     0.999973
# (Mexico, Brazil)         0.999646     0.999981     0.999983     0.999985
# (aluminum, metal)        0.999577     0.999958     0.999972     0.999977
# ...                           ...          ...          ...          ...
# (travel, activity)       0.999151     0.999956     0.999962     0.999966
# (type, kind)             0.999420     0.999962     0.999970     0.999974
# (vodka, brandy)          0.996104     0.999791     0.999808     0.999802
# (vodka, gin)             0.999377     0.999965     0.999971     0.999974
# (wood, forest)           0.999492     0.999967     0.999974     0.999977
#
#                       resid_pre@6  resid_pre@7  resid_pre@8  resid_pre@9
# (Arafat, Jackson)        0.999715     0.999696     0.999577     0.999469
# (Harvard, Yale)          0.999986     0.999987     0.999987     0.999987
# (Japanese, American)     0.999975     0.999976     0.999977     0.999977
# (Mexico, Brazil)         0.999986     0.999987     0.999987     0.999987
# (aluminum, metal)        0.999979     0.999980     0.999981     0.999981
# ...                           ...          ...          ...          ...
# (travel, activity)       0.999969     0.999970     0.999971     0.999971
# (type, kind)             0.999976     0.999977     0.999978     0.999978
# (vodka, brandy)          0.999787     0.999754     0.999641     0.999461
# (vodka, gin)             0.999976     0.999977     0.999977     0.999977
# (wood, forest)           0.999979     0.999980     0.999980     0.999980
#
# [97 rows x 48 columns]

# %% [markdown]
# ### Compute RSA (pearson correlation) between human and machine similarity vectors for each layer

# %%
from scipy.stats import pearsonr

rsa_scores = {}

for hook, machine_vec in cosine_by_hook.items():
  r, _ = pearsonr(machine_vec, human_vec)
  rsa_scores[hook] = r

top_50 = sorted(rsa_scores.items(), key=lambda x: x[1], reverse=True)[:50]

for hook, score in top_50:
  print(f"{hook}: {score:.4f}")
# Out:
# attn_out@0: 0.5531
# resid_pre@0: 0.3552
# mlp_out@0: 0.2517
# resid_post@0: 0.2307
# resid_pre@1: 0.2307
# mlp_out@1: 0.2105
# attn_out@1: 0.2087
# attn_out@10: 0.1925
# attn_out@9: 0.1885
# mlp_out@10: 0.1659
# resid_post@11: 0.1577
# mlp_out@11: 0.1500
# attn_out@2: 0.1495
# attn_out@8: 0.1419
# resid_post@1: 0.1403
# resid_pre@2: 0.1403
# mlp_out@8: 0.1380
# mlp_out@9: 0.1317
# resid_post@2: 0.1302
# resid_pre@3: 0.1302
# resid_post@3: 0.1297
# resid_pre@4: 0.1297
# mlp_out@2: 0.1290
# resid_post@4: 0.1240
# resid_pre@5: 0.1240
# mlp_out@7: 0.1234
# resid_post@7: 0.1185
# resid_pre@8: 0.1185
# mlp_out@4: 0.1183
# resid_post@5: 0.1169
# resid_pre@6: 0.1169
# attn_out@11: 0.1137
# resid_post@6: 0.1114
# resid_pre@7: 0.1114
# resid_post@8: 0.1110
# resid_pre@9: 0.1110
# resid_post@10: 0.1087
# resid_pre@11: 0.1087
# mlp_out@6: 0.1081
# resid_post@9: 0.1029
# resid_pre@10: 0.1029
# attn_out@7: 0.0997
# mlp_out@5: 0.0980
# mlp_out@3: 0.0662
# attn_out@3: 0.0327
# attn_out@4: 0.0286
# attn_out@6: 0.0243
# attn_out@5: 0.0231
